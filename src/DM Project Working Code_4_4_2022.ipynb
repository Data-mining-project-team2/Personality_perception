# %%
# Read the first set of data from Arts and Painting category

import pandas as pd

df = pd.read_csv('C:\\Users\\Dell\\Data Mining Project\\openness\\masterData\\master_data_03_16.csv')
df.drop(['Unnamed: 0', 'Index',  
                'Location', 'Subcategory',
       'Unnamed: 5'], axis=1, inplace=True)
df
# Out:
#                 Name                                             Tweets
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
# [167 rows x 2 columns]

# %%
# Creating cleaned Corpus , Corpus is a collection of text organized into datasets
# Stop words are commonly used in Text Mining and Natural Language Processing (NLP) to 
# eliminate words that are so commonly used that they carry very little useful information.
# nltk - natural language toolkit
# Punkt Sentence Tokenizer. This tokenizer divides a text into a list of sentences by using an unsupervised algorithm
# word tokenization is splitting the phrases, sentences into smaller units such as words

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
print(stopwords.words('english'))
 
stop_words = set(stopwords.words('english'))

stop_words
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
import nltk

from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# subset a df with tweets only to get the tokens further

df_tweets = df[['Tweets']]
df_tweets
# Out:
#                                                 Tweets
# 0    IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1    RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2    RT Ranjandatta Happening today at PM MST Join ...
# 3    LeadershipArts alumns be sure to register for ...
# 4    RT ocsculturalarts Today on Day  of Arts in Ed...
# ..                                                 ...
# 162  StudioShot  Art Painting ArtsNI visualart Work...
# 163  History Repeating Oil Charcoal and Photo Trans...
# 164  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165  Working on figures today Art ArtsNI VisualArt ...
# 166  RT PaintingText New interview with the painter...
#
# [167 rows x 1 columns]

# %%
# Tokenize the words

import nltk
from nltk.corpus import stopwords
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
# word_tokens = word_tokenize(example_sent)

df_tweets = df["Tweets"]
word_token_list = []
filtered_tweet = []

for i in range(len(df_tweets.index)):
#     print(df_tweets[i])
    word_token = word_tokenize(df_tweets[i])
    word_token_list.append(word_token)
    
for j in word_token_list:
#     print(j)
    for k in j:
        if k not in stop_words:
            filtered_tweet.append(k)

            
            
word_token_list

# list(filter(lambda word: word not in stop_words, df_tweets[0]))
# df_tweets["Tweets"].apply(lambda x: [item for item in x if item not in stop_words])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['IMEGAArts',
#   'sjwjubilee',
#   'Synova',
#   'CodeENSH',
#   'jeremyusa',
#   'WartTheWizard',
#   'Doncates',
#   'Their',
#   'kind',
#   'never',
#   'calls',
#   'out',
#   'actual',
#   'racists',
#   'They',
#   'only',
#   'use',
#   'the',
#   'term',
#   'as',
#   'a',
#   'club',
#   'to',
#   'silence',
#   'people',
#   'who',
#   'call',
#   'them',
#   'out',
#   'on',
#   'their',
#   'bullshit',
#   'Thats',
#   'why',
#   'you',
#   'can',
#   'never',
#   'believe',
#   'them',
#   'when',
#   'they',
#   'call',
#   'someone',
#   'that',
#   'or',
#   'any',
#   'other',
#   'form',
#   'of',
#   'bigotry'],
#  ['RT',
#   'WoodenPlank',
#   'Mr',
#   'Arts',
#   'amp',
#   'Crafts',
#   'smashbros',
#   'smash',
#   'smashultimate',
#   'smashbrosultimate',
#   'nintendo',
#   'nintendoswitch',
# ...

# %%
# adding the tokenized list to a dataframe

df1 = pd.DataFrame(word_token_list)
df1['tokenized_tweets']=df1.apply(lambda row: row.dropna().tolist(), axis=1)
df_token = df1[['tokenized_tweets']]
df_token
# Out:
#                                       tokenized_tweets
# 0    [IMEGAArts, sjwjubilee, Synova, CodeENSH, jere...
# 1    [RT, WoodenPlank, Mr, Arts, amp, Crafts, smash...
# 2    [RT, Ranjandatta, Happening, today, at, PM, MS...
# 3    [LeadershipArts, alumns, be, sure, to, registe...
# 4    [RT, ocsculturalarts, Today, on, Day, of, Arts...
# ..                                                 ...
# 162  [StudioShot, Art, Painting, ArtsNI, visualart,...
# 163  [History, Repeating, Oil, Charcoal, and, Photo...
# 164  [RDH, MAY, Blog, May, VisualArt, ArtsNI, Paint...
# 165  [Working, on, figures, today, Art, ArtsNI, Vis...
# 166  [RT, PaintingText, New, interview, with, the, ...
#
# [167 rows x 1 columns]

# %%
# new df to combine tokenized df with original df

df_nlp = pd.concat([df.reset_index(drop=True), df_token], axis=1)
df_nlp
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                       tokenized_tweets
# ...

# %%
# removing stowords from tweets and adding it to the dataframe

from nltk.corpus import stopwords
stop = stopwords.words('english')


df_nlp['tweets_without_stopwords'] = df_nlp['Tweets'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_nlp
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                       tokenized_tweets  \
# ...

# %%
df
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                tweet_without_stopwords
# ...

# %%
word_token_list
# Out:
# [['IMEGAArts',
#   'sjwjubilee',
#   'Synova',
#   'CodeENSH',
#   'jeremyusa',
#   'WartTheWizard',
#   'Doncates',
#   'Their',
#   'kind',
#   'never',
#   'calls',
#   'out',
#   'actual',
#   'racists',
#   'They',
#   'only',
#   'use',
#   'the',
#   'term',
#   'as',
#   'a',
#   'club',
#   'to',
#   'silence',
#   'people',
#   'who',
#   'call',
#   'them',
#   'out',
#   'on',
#   'their',
#   'bullshit',
#   'Thats',
#   'why',
#   'you',
#   'can',
#   'never',
#   'believe',
#   'them',
#   'when',
#   'they',
#   'call',
#   'someone',
#   'that',
#   'or',
#   'any',
#   'other',
#   'form',
#   'of',
#   'bigotry'],
#  ['RT',
#   'WoodenPlank',
#   'Mr',
#   'Arts',
#   'amp',
#   'Crafts',
#   'smashbros',
#   'smash',
#   'smashultimate',
#   'smashbrosultimate',
#   'nintendo',
#   'nintendoswitch',
#   'kingdomhearts',
#   'pokemon',
#   'h'],
#  ['RT',
#   'Ranjandatta',
#   'Happening',
#   'today',
#   'at',
#   'PM',
#   'MST',
#   'Join',
#   'here',
# ...

# %%
df1 = pd.DataFrame(word_token_list)
df1['tokenized_tweets']=df1.apply(lambda row: row.dropna().tolist(), axis=1)
df_token = df1[['tokenized_tweets']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aba66ed737f5> in <module>
# ----> 1 df1 = pd.DataFrame(word_token_list)
#       2 df1['tokenized_tweets']=df1.apply(lambda row: row.dropna().tolist(), axis=1)
#       3 df_token = df1[['tokenized_tweets']]
#
# NameError: name 'word_token_list' is not defined

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

df['tweet_without_stopwords'] = df['Tweets'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
df
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                           token_tweets  \
# ...

# %%
df_nlp = pd.concat([df.reset_index(drop=True), df_token], axis=1)
df_nlp
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                            token_tweet
# ...

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

df['tweet_without_stopwords'] = df['Tweets'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
df
# Out:
#                 Name                                             Tweets  \
# 0    NobodyAndNoOne7  IMEGAArts sjwjubilee Synova CodeENSH jeremyusa...
# 1       AniKpopTrash  RT WoodenPlank Mr Arts amp Crafts\n\nsmashbros...
# 2       PrangeMartin  RT Ranjandatta Happening today at PM MST Join ...
# 3            ok4arts  LeadershipArts alumns be sure to register for ...
# 4          HESSPLASH  RT ocsculturalarts Today on Day  of Arts in Ed...
# ..               ...                                                ...
# 162     BKieltArtist  StudioShot  Art Painting ArtsNI visualart Work...
# 163     BKieltArtist  History Repeating Oil Charcoal and Photo Trans...
# 164     BKieltArtist  RDH  MAY  Blog May VisualArt ArtsNI Painting  ...
# 165     BKieltArtist  Working on figures today Art ArtsNI VisualArt ...
# 166     BKieltArtist  RT PaintingText New interview with the painter...
#
#                                tweet_without_stopwords
# ...

# %%
token_df = pd.Dataframe(word_token_list)
token_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-265927408713> in <module>
# ----> 1 token_df = pd.Dataframe(word_token_list)
#       2 token_df
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df_tweets[0]
# Out:
# 'IMEGAArts sjwjubilee Synova CodeENSH jeremyusa WartTheWizard Doncates Their kind never calls out actual racists They only use the term as a club to silence people who call them out on their bullshit Thats why you can never believe them when they call someone that or any other form of bigotry'

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...
