# %%
# Read the first set of data from Arts and Painting category

import pandas as pd

df = pd.read_csv('C:\\Users\\Dell\\Data Mining Project\\dataset\\tweets_barackObama.csv')
# df.drop(['Unnamed: 0', 'Index',  
#                 'Location', 'Subcategory',
#        'Unnamed: 5'], axis=1, inplace=True)
df
# Out:
#                      id                 created_at  \
# 0   1269065755179524096  2020-06-06 00:37:08+00:00
# 1   1268940899616243715  2020-06-05 16:21:00+00:00
# 2   1268940899616243715  2020-06-05 16:21:00+00:00
# 3   1268682939799425024  2020-06-04 23:15:58+00:00
# 4   1268682939799425024  2020-06-04 23:15:58+00:00
# 5   1268682938251710464  2020-06-04 23:15:58+00:00
# 6   1268682938251710464  2020-06-04 23:15:58+00:00
# 7   1268682936968241157  2020-06-04 23:15:57+00:00
# 8   1268682936968241157  2020-06-04 23:15:57+00:00
# 9   1268682936221609994  2020-06-04 23:15:57+00:00
# 10  1506690376471621634  2020-06-04 23:15:57+00:00
# 11  1268529169702543360  2020-06-04 13:04:56+00:00
# 12  1268529169702543360  2020-06-04 13:04:56+00:00
# 13  1268196828140503042  2020-06-03 15:04:20+00:00
# 14  1506662260588089357  2020-06-03 15:04:20+00:00
# 15  1506662260588089357  2022-03-23 16:00:50+00:00
#
#                                                  text
# 0   Weâ€™ve seen the power that our voices have wh...
# 1   I heard Betty Reid Soskin is retiring at 100, ...
# 2   On National Gun Violence Awareness Day, we #We...
# 3   I'm proud of Titus, Ashton, Thaddeus, Jalen, M...
# 4   Third, every city in this country should be a ...
# 5   Today @POTUS announced that the U.S. will be w...
# 6   Second, every mayor should review their use of...
# 7   As the first woman to serve as Americaâ€™s top...
# 8   First, there are specific evidence-based refor...
# 9   The other day, I called up DonnaMarie, Steve, ...
# 10  Real change requires protest to highlight a pr...
# 11  RT @POTUS: Twelve years ago, I proudly stood b...
# 12  In our @MBK_Alliance town hall yesterday, I me...
# 13  .@POTUSâ€™s American Rescue Plan helped streng...
# 14  And third, an extraordinary essay by the forme...
# 15  During the pandemic, the Affordable Care Act h...

# %%
# Creating Openness dictionary - arts, painting, music, creative, imaginative, 

openness_dict = '''#artgallery, 
#artnews,
#artinfo,
#painting,
#photo,
#openaccessarticle,
#openscience,
#access,
#issue,
#journals,
#papers,
#scienceopen, 
#photography,  
#abstract,
#acrylic, 
#watercolor,
#music,
#video,
#musiclove,
#newmusic,
#nowplaying,
#radio,
#live,
#apple,
#life,
#hiphop,
#artist,
#musicartist,
#rock,
#music,
#musician,
#musicians,
#musicproducer,
#musicvideo,
#musicman,
#musicismylife,
#musicianlife,
#musicmonday,
#musicstudio,
#soundcloud,
#podcast,
#spotify,
#applemusic,
#tidal,
#musicstreaming,
#itunes,
#AmWriting,
#WritersLife,
#WriterWednesday,
#WriteTip,
#WordCount,
#FollowFriday,
#FridayReads,
#WritingPrompt,
#BookGiveaway,
#TuesdayMotivation, 
#CharityTuesday,
#TravelTuesday,
#TuesdayThoughts,
#SampleSunday,
#meme,
#usa,
#freedom,
#america,
#open,
#openness,
#argentina,
#news,
#blacklivesmatter,
#trump,
#covid,
#feminism'''
openness_dict
# Out:
# '#artgallery, \n#artnews,\n#artinfo,\n#painting,\n#photo,\n#openaccessarticle,\n#openscience,\n#access,\n#issue,\n#journals,\n#papers,\n#scienceopen, \n#photography,  \n#abstract,\n#acrylic, \n#watercolor,\n#music,\n#video,\n#musiclove,\n#newmusic,\n#nowplaying,\n#radio,\n#live,\n#apple,\n#life,\n#hiphop,\n#artist,\n#musicartist,\n#rock,\n#music,\n#musician,\n#musicians,\n#musicproducer,\n#musicvideo,\n#musicman,\n#musicismylife,\n#musicianlife,\n#musicmonday,\n#musicstudio,\n#soundcloud,\n#podcast,\n#spotify,\n#applemusic,\n#tidal,\n#musicstreaming,\n#itunes,\n#AmWriting,\n#WritersLife,\n#WriterWednesday,\n#WriteTip,\n#WordCount,\n#FollowFriday,\n#FridayReads,\n#WritingPrompt,\n#BookGiveaway,\n#TuesdayMotivation, \n#CharityTuesday,\n#TravelTuesday,\n#TuesdayThoughts,\n#SampleSunday,\n#meme,\n#usa,\n#freedom,\n#america,\n#open,\n#openness,\n#argentina,\n#news,\n#blacklivesmatter,\n#trump,\n#covid,\n#feminism'

# %%
# agreeableness dictionary

agree_dict = '''
#weekend,
#sunday,
#youtube,
#film,
#comedy,
#sports,
#starwars,
#apple,
#joy,
#cover,
#movies,
#words,
#spotify,
#baseball,
#podcast,
#entertainment,
#kindness,
#mlb,
#google,
#thinking,
#agreeable,
#localeconomy,
#ethicalliving,
#traceability,
#sustainablelife,
#familywork,
#sociallyresponsible,
#fairtradefortnight,
#socialenterprise,
#preciousplastic,
#veggiehotels,
#givingback,
#community,
#givingtuesday,
#charity,
#kids,
#year,
#charities,
#love,
#toy,
#giving,
#support,
#time,
#drive,
#saturday,
#holiday,
#today,
#christmas,
#shop,
#tuesday,
#big,
#tomorrow,
#volunteering,
#children,
#life,
#gratitude,
#empathy,
#sympathy,
#thank
'''
agree_dict
# Out:
# '\n#weekend,\n#sunday,\n#youtube,\n#film,\n#comedy,\n#sports,\n#starwars,\n#apple,\n#joy,\n#cover,\n#movies,\n#words,\n#spotify,\n#baseball,\n#podcast,\n#entertainment,\n#kindness,\n#mlb,\n#google,\n#thinking,\n#agreeable,\n#localeconomy,\n#ethicalliving,\n#traceability,\n#sustainablelife,\n#familywork,\n#sociallyresponsible,\n#fairtradefortnight,\n#socialenterprise,\n#preciousplastic,\n#veggiehotels,\n#givingback,\n#community,\n#givingtuesday,\n#charity,\n#kids,\n#year,\n#charities,\n#love,\n#toy,\n#giving,\n#support,\n#time,\n#drive,\n#saturday,\n#holiday,\n#today,\n#christmas,\n#shop,\n#tuesday,\n#big,\n#tomorrow,\n#volunteering,\n#children,\n#life,\n#gratitude,\n#empathy,\n#sympathy,\n#thank\n'

# %%
openness_list = openness_dict.split(",")
openness_list
# Out:
# ['#artgallery',
#  ' \n#artnews',
#  '\n#artinfo',
#  '\n#painting',
#  '\n#photo',
#  '\n#openaccessarticle',
#  '\n#openscience',
#  '\n#access',
#  '\n#issue',
#  '\n#journals',
#  '\n#papers',
#  '\n#scienceopen',
#  ' \n#photography',
#  '  \n#abstract',
#  '\n#acrylic',
#  ' \n#watercolor',
#  '\n#music',
#  '\n#video',
#  '\n#musiclove',
#  '\n#newmusic',
#  '\n#nowplaying',
#  '\n#radio',
#  '\n#live',
#  '\n#apple',
#  '\n#life',
#  '\n#hiphop',
#  '\n#artist',
#  '\n#musicartist',
#  '\n#rock',
#  '\n#music',
#  '\n#musician',
#  '\n#musicians',
#  '\n#musicproducer',
#  '\n#musicvideo',
#  '\n#musicman',
#  '\n#musicismylife',
#  '\n#musicianlife',
#  '\n#musicmonday',
#  '\n#musicstudio',
#  '\n#soundcloud',
#  '\n#podcast',
#  '\n#spotify',
#  '\n#applemusic',
#  '\n#tidal',
#  '\n#musicstreaming',
#  '\n#itunes',
#  '\n#AmWriting',
#  '\n#WritersLife',
#  '\n#WriterWednesday',
#  '\n#WriteTip',
#  '\n#WordCount',
#  '\n#FollowFriday',
#  '\n#FridayReads',
#  '\n#WritingPrompt',
#  '\n#BookGiveaway',
#  '\n#TuesdayMotivation',
#  ' \n#CharityTuesday',
#  '\n#TravelTuesday',
#  '\n#TuesdayThoughts',
#  '\n#SampleSunday',
#  '\n#meme',
#  '\n#usa',
#  '\n#freedom',
#  '\n#america',
#  '\n#open',
#  '\n#openness',
#  '\n#argentina',
#  '\n#news',
#  '\n#blacklivesmatter',
#  '\n#trump',
#  '\n#covid',
#  '\n#feminism']

# %%
import re

open_cleaned = [re.sub(r"[^a-zA-Z0-9]", "", file) for file in openness_list]
open_cleaned
# Out:
# ['artgallery',
#  'artnews',
#  'artinfo',
#  'painting',
#  'photo',
#  'openaccessarticle',
#  'openscience',
#  'access',
#  'issue',
#  'journals',
#  'papers',
#  'scienceopen',
#  'photography',
#  'abstract',
#  'acrylic',
#  'watercolor',
#  'music',
#  'video',
#  'musiclove',
#  'newmusic',
#  'nowplaying',
#  'radio',
#  'live',
#  'apple',
#  'life',
#  'hiphop',
#  'artist',
#  'musicartist',
#  'rock',
#  'music',
#  'musician',
#  'musicians',
#  'musicproducer',
#  'musicvideo',
#  'musicman',
#  'musicismylife',
#  'musicianlife',
#  'musicmonday',
#  'musicstudio',
#  'soundcloud',
#  'podcast',
#  'spotify',
#  'applemusic',
#  'tidal',
#  'musicstreaming',
#  'itunes',
#  'AmWriting',
#  'WritersLife',
#  'WriterWednesday',
#  'WriteTip',
#  'WordCount',
#  'FollowFriday',
#  'FridayReads',
#  'WritingPrompt',
#  'BookGiveaway',
#  'TuesdayMotivation',
#  'CharityTuesday',
#  'TravelTuesday',
#  'TuesdayThoughts',
#  'SampleSunday',
#  'meme',
#  'usa',
#  'freedom',
#  'america',
#  'open',
#  'openness',
#  'argentina',
#  'news',
#  'blacklivesmatter',
#  'trump',
#  'covid',
#  'feminism']

# %%
# Function to remove hashtags and special characters
# re - regular expression

import re

def remove_hashtags(str):
    cleaned_dict = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",str)
    return cleaned_dict

# %%
agree_list = agree_dict.split(",")
agree_list
# Out:
# ['\n#weekend',
#  '\n#sunday',
#  '\n#youtube',
#  '\n#film',
#  '\n#comedy',
#  '\n#sports',
#  '\n#starwars',
#  '\n#apple',
#  '\n#joy',
#  '\n#cover',
#  '\n#movies',
#  '\n#words',
#  '\n#spotify',
#  '\n#baseball',
#  '\n#podcast',
#  '\n#entertainment',
#  '\n#kindness',
#  '\n#mlb',
#  '\n#google',
#  '\n#thinking',
#  '\n#agreeable',
#  '\n#localeconomy',
#  '\n#ethicalliving',
#  '\n#traceability',
#  '\n#sustainablelife',
#  '\n#familywork',
#  '\n#sociallyresponsible',
#  '\n#fairtradefortnight',
#  '\n#socialenterprise',
#  '\n#preciousplastic',
#  '\n#veggiehotels',
#  '\n#givingback',
#  '\n#community',
#  '\n#givingtuesday',
#  '\n#charity',
#  '\n#kids',
#  '\n#year',
#  '\n#charities',
#  '\n#love',
#  '\n#toy',
#  '\n#giving',
#  '\n#support',
#  '\n#time',
#  '\n#drive',
#  '\n#saturday',
#  '\n#holiday',
#  '\n#today',
#  '\n#christmas',
#  '\n#shop',
#  '\n#tuesday',
#  '\n#big',
#  '\n#tomorrow',
#  '\n#volunteering',
#  '\n#children',
#  '\n#life',
#  '\n#gratitude',
#  '\n#empathy',
#  '\n#sympathy',
#  '\n#thank\n']

# %%
import re

agree_cleaned = [re.sub(r"[^a-zA-Z0-9]", "", file) for file in agree_list]
agree_cleaned
# Out:
# ['weekend',
#  'sunday',
#  'youtube',
#  'film',
#  'comedy',
#  'sports',
#  'starwars',
#  'apple',
#  'joy',
#  'cover',
#  'movies',
#  'words',
#  'spotify',
#  'baseball',
#  'podcast',
#  'entertainment',
#  'kindness',
#  'mlb',
#  'google',
#  'thinking',
#  'agreeable',
#  'localeconomy',
#  'ethicalliving',
#  'traceability',
#  'sustainablelife',
#  'familywork',
#  'sociallyresponsible',
#  'fairtradefortnight',
#  'socialenterprise',
#  'preciousplastic',
#  'veggiehotels',
#  'givingback',
#  'community',
#  'givingtuesday',
#  'charity',
#  'kids',
#  'year',
#  'charities',
#  'love',
#  'toy',
#  'giving',
#  'support',
#  'time',
#  'drive',
#  'saturday',
#  'holiday',
#  'today',
#  'christmas',
#  'shop',
#  'tuesday',
#  'big',
#  'tomorrow',
#  'volunteering',
#  'children',
#  'life',
#  'gratitude',
#  'empathy',
#  'sympathy',
#  'thank']

# %%
df_tweets = df[["text"]]
df_tweets
# Out:
#                                                  text
# 0   Weâ€™ve seen the power that our voices have wh...
# 1   I heard Betty Reid Soskin is retiring at 100, ...
# 2   On National Gun Violence Awareness Day, we #We...
# 3   I'm proud of Titus, Ashton, Thaddeus, Jalen, M...
# 4   Third, every city in this country should be a ...
# 5   Today @POTUS announced that the U.S. will be w...
# 6   Second, every mayor should review their use of...
# 7   As the first woman to serve as Americaâ€™s top...
# 8   First, there are specific evidence-based refor...
# 9   The other day, I called up DonnaMarie, Steve, ...
# 10  Real change requires protest to highlight a pr...
# 11  RT @POTUS: Twelve years ago, I proudly stood b...
# 12  In our @MBK_Alliance town hall yesterday, I me...
# 13  .@POTUSâ€™s American Rescue Plan helped streng...
# 14  And third, an extraordinary essay by the forme...
# 15  During the pandemic, the Affordable Care Act h...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# print(stopwords.words('english'))

df_tweets = df["text"]
word_token_list = []
filtered_tweet = []

for i in range(len(df_tweets.index)):
    word_token = word_tokenize(df_tweets[i])
    word_token_list.append(word_token)
    
word_token_list
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['Weâ€™ve',
#   'seen',
#   'the',
#   'power',
#   'that',
#   'our',
#   'voices',
#   'have',
#   'when',
#   'we',
#   'speak',
#   'out',
#   'about',
#   'injusticeâ€',
#   '“',
#   'â€',
#   '“',
#   'but',
#   'we',
#   'also',
#   'know',
#   'the',
#   'toll',
#   'that',
#   'it',
#   'takeâ€¦',
#   'https',
#   ':',
#   '//t.co/ObdM8RkgEf'],
#  ['I',
#   'heard',
#   'Betty',
#   'Reid',
#   'Soskin',
#   'is',
#   'retiring',
#   'at',
#   '100',
#   ',',
#   'and',
#   'want',
#   'to',
#   'congratulate',
#   'her',
#   'for',
#   'more',
#   'than',
#   'a',
#   'decade',
#   'of',
#   'service',
#   'as',
#   'a',
#   'Nâ€¦',
#   'https',
#   ':',
#   '//t.co/uPYzkS8jri'],
#  ['On',
#   'National',
#   'Gun',
#   'Violence',
#   'Awareness',
#   'Day',
#   ',',
#   'we',
#   '#',
#   'WearOrange',
#   'to',
#   'honor',
#   'the',
#   'victims',
#   'and',
#   'survivors',
#   'of',
#   'gun',
#   'violenceâ€',
#   '“',
#   'â€',
#   '“',
#   'which',
#   'coâ€¦',
#   'https',
#   ':',
#   '//t.co/cNV3OQ1knd'],
#  ['I',
#   "'m",
#   'proud',
#   'of',
#   'Titus',
#   ',',
#   'Ashton',
#   ',',
#   'Thaddeus',
#   ',',
#   'Jalen',
#   ',',
#   'McKinley',
#   'and',
#   'Peter',
#   'for',
#   'representing',
#   '@',
#   'MBK_Alliance',
#   'at',
#   '@',
#   'MarchMadnessMBB.â€¦',
#   'https',
#   ':',
#   '//t.co/57h6XDA0jp'],
#  ['Third',
#   ',',
#   'every',
#   'city',
#   'in',
#   'this',
#   'country',
#   'should',
#   'be',
#   'a',
#   '@',
#   'MBK_Alliance',
#   'community',
#   '.',
#   'We',
#   'have',
#   '250',
#   'cities',
#   ',',
#   'counties',
#   ',',
#   'and',
#   'tribal',
#   'natâ€¦',
#   'https',
#   ':',
#   '//t.co/ELtGDZNoZD'],
#  ['Today',
#   '@',
#   'POTUS',
#   'announced',
#   'that',
#   'the',
#   'U.S.',
#   'will',
#   'be',
#   'welcoming',
#   '100,000',
#   'refugees',
#   'fleeing',
#   'the',
#   'war',
#   'in',
#   'Ukraine',
#   '.',
#   'Â',
#   'This',
#   'is',
#   'the',
#   'râ€¦',
#   'https',
#   ':',
#   '//t.co/wlyZASCR4i'],
#  ['Second',
#   ',',
#   'every',
#   'mayor',
#   'should',
#   'review',
#   'their',
#   'use',
#   'of',
#   'force',
#   'policies',
#   'with',
#   'members',
#   'of',
#   'their',
#   'community',
#   'and',
#   'commit',
#   'to',
#   'reportâ€¦',
#   'https',
#   ':',
#   '//t.co/22stCoND3e'],
#  ['As',
#   'the',
#   'first',
#   'woman',
#   'to',
#   'serve',
#   'as',
#   'Americaâ€™s',
#   'top',
#   'diplomat',
#   ',',
#   'Madeleine',
#   'Albright',
#   'was',
#   'a',
#   'champion',
#   'for',
#   'democratic',
#   'values',
#   '.',
#   'Micâ€¦',
#   'https',
#   ':',
#   '//t.co/FPuAFRQ0rY'],
#  ['First',
#   ',',
#   'there',
#   'are',
#   'specific',
#   'evidence-based',
#   'reforms',
#   'that',
#   'would',
#   'build',
#   'trust',
#   ',',
#   'save',
#   'lives',
#   ',',
#   'and',
#   'lead',
#   'to',
#   'a',
#   'decrease',
#   'in',
#   'crimâ€¦',
#   'https',
#   ':',
#   '//t.co/Y9NYL1AmEp'],
#  ['The',
#   'other',
#   'day',
#   ',',
#   'I',
#   'called',
#   'up',
#   'DonnaMarie',
#   ',',
#   'Steve',
#   ',',
#   'and',
#   'Amy',
#   'to',
#   'hear',
#   'how',
#   'the',
#   'Affordable',
#   'Care',
#   'Act',
#   'changed',
#   'their',
#   'lives',
#   'and',
#   'tâ€¦',
#   'https',
#   ':',
#   '//t.co/aBFPQgc90e'],
#  ['Real',
#   'change',
#   'requires',
#   'protest',
#   'to',
#   'highlight',
#   'a',
#   'problem',
#   ',',
#   'and',
#   'politics',
#   'to',
#   'implement',
#   'practical',
#   'solutions',
#   'and',
#   'laws',
#   '.',
#   'As',
#   'I',
#   'mâ€¦',
#   'https',
#   ':',
#   '//t.co/Yg1ta1Ky1n'],
#  ['RT',
#   '@',
#   'POTUS',
#   ':',
#   'Twelve',
#   'years',
#   'ago',
#   ',',
#   'I',
#   'proudly',
#   'stood',
#   'beside',
#   'President',
#   '@',
#   'BarackObama',
#   'as',
#   'he',
#   'signed',
#   'into',
#   'law',
#   'the',
#   'most',
#   'consequential',
#   'expansion',
#   'of',
#   'healthâ€¦'],
#  ['In',
#   'our',
#   '@',
#   'MBK_Alliance',
#   'town',
#   'hall',
#   'yesterday',
#   ',',
#   'I',
#   'mentioned',
#   'James',
#   'Baldwin',
#   "'s",
#   'The',
#   'Fire',
#   'Next',
#   'Time',
#   '.',
#   'From',
#   '1962',
#   ',',
#   'it',
#   'remains',
#   'a',
#   'sâ€¦',
#   'https',
#   ':',
#   '//t.co/ywCjOXeBU3'],
#  ['.',
#   '@',
#   'POTUSâ€™s',
#   'American',
#   'Rescue',
#   'Plan',
#   'helped',
#   'strengthen',
#   'the',
#   'Affordable',
#   'Care',
#   'Act',
#   'by',
#   'lowering',
#   'costs',
#   'and',
#   'encouraging',
#   'a',
#   'recordâ€¦',
#   'https',
#   ':',
#   '//t.co/i9rF1P0Dl0'],
#  ['And',
#   'third',
#   ',',
#   'an',
#   'extraordinary',
#   'essay',
#   'by',
#   'the',
#   'former',
#   'Chairman',
#   'of',
#   'the',
#   'Joint',
#   'Chiefs',
#   'of',
#   'Staff',
#   'of',
#   'the',
#   'U.S.',
#   'Armed',
#   'Forces',
#   ',',
#   'Mikâ€¦',
#   'https',
#   ':',
#   '//t.co/JCBGWiKaAq'],
#  ['During',
#   'the',
#   'pandemic',
#   ',',
#   'the',
#   'Affordable',
#   'Care',
#   'Act',
#   'helped',
#   'make',
#   'vaccines',
#   'and',
#   'COVID-19',
#   'tests',
#   'available',
#   'for',
#   'free',
#   ',',
#   'covered',
#   'emâ€¦',
#   'https',
#   ':',
#   '//t.co/QuZHfxhUct']]

# %%
df1 = pd.DataFrame(word_token_list)
df1['tokenized_tweets']=df1.apply(lambda row: row.dropna().tolist(), axis=1)
df_token = df1[['tokenized_tweets']]
df_token
# Out:
#                                      tokenized_tweets
# 0   [Weâ€™ve, seen, the, power, that, our, voices,...
# 1   [I, heard, Betty, Reid, Soskin, is, retiring, ...
# 2   [On, National, Gun, Violence, Awareness, Day, ...
# 3   [I, 'm, proud, of, Titus, ,, Ashton, ,, Thadde...
# 4   [Third, ,, every, city, in, this, country, sho...
# 5   [Today, @, POTUS, announced, that, the, U.S., ...
# 6   [Second, ,, every, mayor, should, review, thei...
# 7   [As, the, first, woman, to, serve, as, America...
# 8   [First, ,, there, are, specific, evidence-base...
# 9   [The, other, day, ,, I, called, up, DonnaMarie...
# 10  [Real, change, requires, protest, to, highligh...
# 11  [RT, @, POTUS, :, Twelve, years, ago, ,, I, pr...
# 12  [In, our, @, MBK_Alliance, town, hall, yesterd...
# 13  [., @, POTUSâ€™s, American, Rescue, Plan, help...
# 14  [And, third, ,, an, extraordinary, essay, by, ...
# 15  [During, the, pandemic, ,, the, Affordable, Ca...

# %%
df_cleaned = pd.concat([df.reset_index(drop=True), df_token], axis=1)
df_cleaned
# Out:
#                      id                 created_at  \
# 0   1269065755179524096  2020-06-06 00:37:08+00:00
# 1   1268940899616243715  2020-06-05 16:21:00+00:00
# 2   1268940899616243715  2020-06-05 16:21:00+00:00
# 3   1268682939799425024  2020-06-04 23:15:58+00:00
# 4   1268682939799425024  2020-06-04 23:15:58+00:00
# 5   1268682938251710464  2020-06-04 23:15:58+00:00
# 6   1268682938251710464  2020-06-04 23:15:58+00:00
# 7   1268682936968241157  2020-06-04 23:15:57+00:00
# 8   1268682936968241157  2020-06-04 23:15:57+00:00
# 9   1268682936221609994  2020-06-04 23:15:57+00:00
# 10  1506690376471621634  2020-06-04 23:15:57+00:00
# 11  1268529169702543360  2020-06-04 13:04:56+00:00
# 12  1268529169702543360  2020-06-04 13:04:56+00:00
# 13  1268196828140503042  2020-06-03 15:04:20+00:00
# 14  1506662260588089357  2020-06-03 15:04:20+00:00
# 15  1506662260588089357  2022-03-23 16:00:50+00:00
#
#                                                  text  \
# 0   Weâ€™ve seen the power that our voices have wh...
# 1   I heard Betty Reid Soskin is retiring at 100, ...
# 2   On National Gun Violence Awareness Day, we #We...
# 3   I'm proud of Titus, Ashton, Thaddeus, Jalen, M...
# 4   Third, every city in this country should be a ...
# 5   Today @POTUS announced that the U.S. will be w...
# 6   Second, every mayor should review their use of...
# 7   As the first woman to serve as Americaâ€™s top...
# 8   First, there are specific evidence-based refor...
# 9   The other day, I called up DonnaMarie, Steve, ...
# 10  Real change requires protest to highlight a pr...
# 11  RT @POTUS: Twelve years ago, I proudly stood b...
# 12  In our @MBK_Alliance town hall yesterday, I me...
# 13  .@POTUSâ€™s American Rescue Plan helped streng...
# 14  And third, an extraordinary essay by the forme...
# 15  During the pandemic, the Affordable Care Act h...
#
#                                      tokenized_tweets
# 0   [Weâ€™ve, seen, the, power, that, our, voices,...
# 1   [I, heard, Betty, Reid, Soskin, is, retiring, ...
# 2   [On, National, Gun, Violence, Awareness, Day, ...
# 3   [I, 'm, proud, of, Titus, ,, Ashton, ,, Thadde...
# 4   [Third, ,, every, city, in, this, country, sho...
# 5   [Today, @, POTUS, announced, that, the, U.S., ...
# 6   [Second, ,, every, mayor, should, review, thei...
# 7   [As, the, first, woman, to, serve, as, America...
# 8   [First, ,, there, are, specific, evidence-base...
# 9   [The, other, day, ,, I, called, up, DonnaMarie...
# 10  [Real, change, requires, protest, to, highligh...
# 11  [RT, @, POTUS, :, Twelve, years, ago, ,, I, pr...
# 12  [In, our, @, MBK_Alliance, town, hall, yesterd...
# 13  [., @, POTUSâ€™s, American, Rescue, Plan, help...
# 14  [And, third, ,, an, extraordinary, essay, by, ...
# 15  [During, the, pandemic, ,, the, Affordable, Ca...

# %%
df_cleaned["tokenized_tweets"][2][0]
# Out:
# 'On'

# %%
open_cleaned[2]
# Out:
# 'artinfo'
